# %%
from loader import Dataset
import matplotlib.pyplot as plt

# %%
fd = Dataset()

# %%
fd.full_faces_path[0]
# Out:
# '../dat/Faces/ffhq-dataset/images1024x1024/28000/28534.png'

# %%
len(fd)
# Out:
# 70000

# %%
fig = plt.figure()

for i in range(len(fd)):
    sample = fd[i]

    print(i, sample['masked_image'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    ax.imshow(sample["masked_image"])
    if i == 3:
        plt.show()
        break
# Out:
# 0 (1024, 1024, 3)
# 1 (1024, 1024, 3)
# 2 (1024, 1024, 3)
# 3 (1024, 1024, 3)

# %%
import cv2
import os

# %%
params = {'batch_size': 64,
          'shuffle': True,
          'num_worker': 4}

# %%
mask = cv2.imread("../dat/qd_imd/test/00000_test.png")

# %%
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
img = fd[0]["image"]

# %%
plt.imshow(img)

# %%
mask = cv2.resize(mask, (1024, 1024))
mask = mask/255

# %%
img2 = img*mask

# %%
img2 = img2.astype(int)

# %%
plt.imshow(img2)

# %%
"""
Train the model
"""

from torch.utils import data
import torch
import numpy as np
import loss
import matplotlib.pyplot as plt
from model import DeFINe
from loader import Dataset

params = {'batch_size': 1,
          'shuffle': True,
          'num_workers': 4}

max_epochs = 200

training_set = Dataset()
training_generator = data.DataLoader(training_set, **params)

validation_set = Dataset(mask_path='../dat/qd_imd/test/')
validation_generator = data.DataLoader(validation_set, **params)


use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

NET = DeFINe(device=device)
NET.to(device)


params = {'batch_size': 1,
          'shuffle': True,
          'num_workers': 4}

max_epochs = 100

sample = training_set[0]
image = torch.tensor(sample["image"].reshape(1, 1024, 1024, 3), requires_grad=False).to(device)
mask = sample["mask"].reshape(1, 1024, 1024, 3)
masked_image = sample["masked_image"].reshape(1, 1024, 1024, 3)

# %%
for batch in training_generator:
    img = batch["image"]
    mask = batch["mask"]
    masked = batch["masked_image"]
    plt.figure()
    plt.imshow(mask[0])
    plt.figure()
    plt.imshow(masked[0])
    break

# %%
opt = torch.optim.Adam(NET.parameters(), lr=1e-4)
NET.train()

for epoch in range(max_epochs):
    opt.zero_grad()
    pred, mask_ = NET(masked_image, mask )
    actual_loss = loss.l1_loss(pred, image)
    print(actual_loss)
    actual_loss.backward()
    opt.step()
    torch.cuda.empty_cache()

# %%
pred, mask = NET(masked_image, mask)

fig, axis = plt.subplots(1, 2)
axis[0].imshow(masked_image.reshape(1024, 1024, 3))
pred = pred.cpu().detach().numpy()
pred = pred.transpose(0, 2, 3, 1)
axis[0].imshow(pred[0])
plt.show()
