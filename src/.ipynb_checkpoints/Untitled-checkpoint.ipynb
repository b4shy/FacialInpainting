# %%
import os

# %%
faces_path = f'../dat/Faces/ffhq-dataset/images1024x1024/'

# %%
faces =

# %%
for i in os.listdir(faces_path):
    
    face_images = os.listdir(os.path.join(faces_path, i))
    print(face_images)
    print(os.path.join(faces_path, i))
    break
# Out:
# ['28534.png', '28000.png', '28001.png', '28002.png', '28003.png', '28004.png', '28005.png', '28006.png', '28007.png', '28008.png', '28009.png', '28010.png', '28011.png', '28012.png', '28013.png', '28014.png', '28015.png', '28016.png', '28017.png', '28018.png', '28019.png', '28020.png', '28021.png', '28022.png', '28023.png', '28024.png', '28025.png', '28026.png', '28027.png', '28028.png', '28029.png', '28474.png', '28475.png', '28476.png', '28477.png', '28478.png', '28479.png', '28480.png', '28481.png', '28482.png', '28483.png', '28484.png', '28485.png', '28486.png', '28487.png', '28488.png', '28489.png', '28490.png', '28491.png', '28492.png', '28493.png', '28494.png', '28495.png', '28496.png', '28497.png', '28498.png', '28499.png', '28500.png', '28773.png', '28774.png', '28775.png', '28776.png', '28777.png', '28778.png', '28779.png', '28780.png', '28781.png', '28782.png', '28783.png', '28784.png', '28785.png', '28786.png', '28787.png', '28788.png', '28789.png', '28790.png', '28791.pn
# ...
